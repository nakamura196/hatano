# %%
import pandas as pd
import matplotlib.pyplot as plt
import japanize_matplotlib

# %%
class Client:

    def __init__(self, path):

        self.sheets = pd.read_excel(path, sheet_name=None)

    def extract_char(self, term):

        self.term = term

        sheets = self.sheets

        rows_target = []

        for sheet_name, df in sheets.items():

            column_names = df.columns.tolist()

            if column_names[0] != "ID":
                continue

            for i, row in df.iterrows():
                char = row["Char"]
                # print(char)

                if char != term:
                    continue

                rows_target.append(row)

        return pd.DataFrame(rows_target)

    def visualize(self, df):
        # angleをy, besideをx軸にして、散布図を

        # 散布図を作成
        plt.scatter(df['beside'], df['Angle'])

        # 軸の範囲を設定
        plt.xlim(0, 2)
        plt.ylim(0, 30)

            # タイトルと軸ラベルを設定
        plt.title(f'"{self.term}"の比較')
        plt.xlabel('縦横比')
        plt.ylabel('傾き')
        
        plt.show()

# %%
path = "../data/input/単一字種比較用フォーマット20250226.xlsx"

client = Client(path)

term = "左"

df = client.extract_char(term)

df
# Out:
#                  ID Char      X      Y  Width  Height  Angle Aspect    beside  \
# 0  wuyi_0331_01_001    左  236.0  501.0   59.0    44.0  5.826      横  0.572816
# 0  wuyi_1106_01_001    左  229.0  562.0   75.0    40.0  1.685      横  0.652174
# 5  wuyi_1106_01_006    左  227.0  811.0   79.0    34.0  2.291      横  0.699115
# 0  wuyi_2913_01_001    左   16.0  540.0   64.0    49.0  5.356      横  0.566372
# 0  wuyi_2965_01_001    左  234.0  513.0   76.0    36.0  3.013      横  0.678571
#
#    vertical  Center X  Center Y  Inter dist  Char space  Unnamed: 14  \
# 0  0.427184     265.5     523.0         NaN         NaN          NaN
# 0  0.347826     266.5     582.0         NaN         NaN          NaN
# 5  0.300885     266.5     828.0        42.5         8.0          NaN
# 0  0.433628      48.0     564.5         NaN         NaN          NaN
# 0  0.321429     272.0     531.0         NaN         NaN          NaN
#
#   縦長文字・横長文字の比率 Unnamed: 16 Unnamed: 17
# 0     結構Aspect          個数        相対度数
# 0     結構Aspect          個数        相対度数
# 5          NaN         NaN         NaN
# 0     結構Aspect          個数        相対度数
# 0     結構Aspect          個数        相対度数

# %%
client.visualize(df)

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import io
from matplotlib import font_manager
import japanize_matplotlib  # 日本語フォントのサポート

class Client:
    def __init__(self, path):
        self.sheets = pd.read_excel(path, sheet_name=None)
        self.term = None

    def extract_char(self, term):
        self.term = term
        sheets = self.sheets
        rows_target = []

        for sheet_name, df in sheets.items():
            column_names = df.columns.tolist()
            if column_names[0] != "ID":
                continue

            for i, row in df.iterrows():
                char = row["Char"]
                # print(char)
                if char != term:
                    continue
                rows_target.append(row)

        return pd.DataFrame(rows_target)

    def visualize(self, df):
        # Create figure
        fig, ax = plt.subplots()
        
        # 散布図を作成
        ax.scatter(df['beside'], df['Angle'])
        
        # 軸の範囲を設定
        ax.set_xlim(0, 2)
        ax.set_ylim(0, 30)
        
        # タイトルと軸ラベルを設定
        ax.set_title(f'"{self.term}"の比較')
        ax.set_xlabel('縦横比')
        ax.set_ylabel('傾き')
        
        return fig
# Out:
# 2025-04-21 18:14:11.990 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 18:14:11.991 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 18:14:12.034
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/nakamura/git/hatano/kaken/.venv/lib/python3.9/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-04-21 18:14:12.035 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 18:14:12.035 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 18:14:12.035 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 18:14:12.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 18:14:12.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 18:14:12.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
