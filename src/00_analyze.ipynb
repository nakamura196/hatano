# %%
# %reload_ext autoreload
# %autoreload 2
from hatano.core import Client

# %%
# import matplotlib.pyplot as plt
# import japanize_matplotlib
# %matplotlib inline

# %%
path = "../data/input/単一字種比較用フォーマット20250226.xlsx"

client = Client(path)

term = "五"

df = client.extract_char(term)

df
# Out:
#                   ID Char    X     Y  Width  Height  Angle Aspect    beside  \
# 24  wuyi_s046_01_025    五  204   609     43      31 -1.507      横  0.581081
# 40  wuyi_s046_01_041    五  217  1276     34      28  3.576      横  0.548387
#
#     vertical  Center X  Center Y  Inter dist  Char space  Unnamed: 14  \
# 24  0.418919     225.5     624.5         NaN         NaN          NaN
# 40  0.451613     234.0    1290.0        39.5         9.0          NaN
#
#     縦長文字・横長文字の比率  Unnamed: 16  Unnamed: 17
# 24  傾きと構成率（横）の分布          NaN          NaN
# 40           NaN          NaN          NaN

# %%
fig = client.visualize(df)
